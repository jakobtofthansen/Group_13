# %%
## Standard stuff:
import numpy as np, seaborn as sns, pandas as pd
## For text classification:
import nltk, nltk.sentiment, sklearn
# %matplotlib inline

# %%
### Download data as pandas dataframe
import requests
path2data = 'https://raw.githubusercontent.com/snorreralund/scraping_seminar/master/english_review_sample.csv'
df = pd.read_csv(path2data)

# %%
# Download positive and negative sentiment lexicons, split into words and convert to set representation. 
negative = set(requests.get('http://ptrckprry.com/course/ssd/data/negative-words.txt').text.split(';\n')[-1].split('\n'))
positive = set(requests.get('http://ptrckprry.com/course/ssd/data/positive-words.txt').text.split(';\n')[-1].split('\n'))
print(len(negative),len(positive))
# Out:
# 4784 2007

# %%
df = pd.read_csv (r'C:\Users\jtoft\Downloads\dataframe_u_more.csv')

# %%
# # dropping null value columns to avoid errors 
# df.dropna(inplace = True) 
   
df['country'] = df['location'].str.rsplit(',').str[-1] 
df
# Out:
#       Unnamed: 0                                               name  \
# 0              0  Ate here last night with a group of friends.  ...
# 1              1  Awesome!! Delicious food, nice staff.  We had ...
# 2              2  We wanted a nice dinner. We  could place our o...
# 3              3  Restuarant Tight is located off the main shopp...
# 4              4  We concluded our trip to Denmark by stumbling ...
# 5              5  Visited on a Sunday night\nWe booked a table b...
# 6              6  Based on reviews of this establishment, my hus...
# 7              7  Had a late lunch at Tight, ordering off the lu...
# 8              8  A great dinner with most gracious staff for ou...
# 9              9  My husband and I ate here for our last dinner ...
# 10             0  We sat upstairs and had a really delightful lu...
# 11             1  This restaurant was recommended by a friend an...
# 12             2  Nice place for dinner just off the shopping st...
# 13             3  Small dishes Tapas style was served. All three...
# 14             4  Our table was on the second floor—good for peo...
# 15             5  Used TA to find a restaurant and settled on Ti...
# 16             6  We enjoyed our meal at Tight.  I had booked a ...
# 17             7  Lovely restuarant. We were greeted promptly, a...
# 18             8  A very welcoming host that made our visit perf...
# 19             9  Husband and I just had dinner here. I had the ...
# 20             0  This is very centrally located. We tried their...
# 21             1  Found this restaurant after a tip from a local...
# 22             2  Had a very good meal here.\nWhen we booked we ...
# 23             3  Restaurant Tight is an inviting multi-level re...
# 24             4  Came to Tight based on reviews here and Rick S...
# 25             5  A very cozy and nice restaurant with two floor...
# 26             6  Don’t miss this restaurant during your Copenha...
# 27             7  I am currently writing this as I am finishing ...
# 28             8  First time in Copenhagen from Scotland  .. so ...
# 29             9  We used the what’s nearby feature on the app a...
# ...          ...                                                ...
# 2838           0  Ate here last night with a group of friends.  ...
# 2839           1  Awesome!! Delicious food, nice staff.  We had ...
# 2840           2  We wanted a nice dinner. We  could place our o...
# 2841           3  Restuarant Tight is located off the main shopp...
# 2842           4  We concluded our trip to Denmark by stumbling ...
# 2843           5  Visited on a Sunday night\nWe booked a table b...
# 2844           6  Based on reviews of this establishment, my hus...
# 2845           7  Had a late lunch at Tight, ordering off the lu...
# 2846           8  A great dinner with most gracious staff for ou...
# 2847           9  My husband and I ate here for our last dinner ...
# 2848           0  Ate here last night with a group of friends.  ...
# 2849           1  Awesome!! Delicious food, nice staff.  We had ...
# 2850           2  We wanted a nice dinner. We  could place our o...
# 2851           3  Restuarant Tight is located off the main shopp...
# 2852           4  We concluded our trip to Denmark by stumbling ...
# 2853           5  Visited on a Sunday night\nWe booked a table b...
# 2854           6  Based on reviews of this establishment, my hus...
# 2855           7  Had a late lunch at Tight, ordering off the lu...
# 2856           8  A great dinner with most gracious staff for ou...
# 2857           9  My husband and I ate here for our last dinner ...
# 2858           0  Ate here last night with a group of friends.  ...
# 2859           1  Awesome!! Delicious food, nice staff.  We had ...
# 2860           2  We wanted a nice dinner. We  could place our o...
# 2861           3  Restuarant Tight is located off the main shopp...
# 2862           4  We concluded our trip to Denmark by stumbling ...
# 2863           5  Visited on a Sunday night\nWe booked a table b...
# 2864           6  Based on reviews of this establishment, my hus...
# 2865           7  Had a late lunch at Tight, ordering off the lu...
# 2866           8  A great dinner with most gracious staff for ou...
# 2867           9  My husband and I ate here for our last dinner ...
#
#                        location  \
# 0           Waukesha, Wisconsin
# 1              Hong Kong, China
# 2            Sollentuna, Sweden
# 3        London, United Kingdom
# 4                           NaN
# 5       Newquay, United Kingdom
# 6                           NaN
# 7                         Texas
# 8              Aurora, Colorado
# 9     San Francisco, California
# 10      New York City, New York
# 11                Madrid, Spain
# 12            Chicago, Illinois
# 13                          NaN
# 14        Princeton, New Jersey
# 15                          NaN
# 16                      Seattle
# 17                     Cheshire
# 18            Stockholm, Sweden
# 19                         Maui
# 20           Bucharest, Romania
# 21                          NaN
# 22       Surrey, United Kingdom
# 23      New York City, New York
# 24                      Toronto
# 25            Stromstad, Sweden
# 26       Chattanooga, Tennessee
# 27                          NaN
# 28          Copenhagen, Denmark
# 29              Calgary, Canada
# ...                         ...
# 2838        Waukesha, Wisconsin
# 2839           Hong Kong, China
# 2840         Sollentuna, Sweden
# 2841     London, United Kingdom
# 2842                        NaN
# 2843    Newquay, United Kingdom
# 2844                        NaN
# 2845                      Texas
# 2846           Aurora, Colorado
# 2847  San Francisco, California
# 2848        Waukesha, Wisconsin
# 2849           Hong Kong, China
# 2850         Sollentuna, Sweden
# 2851     London, United Kingdom
# 2852                        NaN
# 2853    Newquay, United Kingdom
# 2854                        NaN
# 2855                      Texas
# 2856           Aurora, Colorado
# 2857  San Francisco, California
# 2858        Waukesha, Wisconsin
# 2859           Hong Kong, China
# 2860         Sollentuna, Sweden
# 2861     London, United Kingdom
# 2862                        NaN
# 2863    Newquay, United Kingdom
# 2864                        NaN
# 2865                      Texas
# 2866           Aurora, Colorado
# 2867  San Francisco, California
#
#                                                 bubble  rating  \
# 0     <span class="ui_bubble_rating bubble_40"></span>      40
# 1     <span class="ui_bubble_rating bubble_50"></span>      50
# 2     <span class="ui_bubble_rating bubble_20"></span>      20
# 3     <span class="ui_bubble_rating bubble_40"></span>      40
# 4     <span class="ui_bubble_rating bubble_50"></span>      50
# 5     <span class="ui_bubble_rating bubble_50"></span>      50
# 6     <span class="ui_bubble_rating bubble_50"></span>      50
# 7     <span class="ui_bubble_rating bubble_50"></span>      50
# 8     <span class="ui_bubble_rating bubble_50"></span>      50
# 9     <span class="ui_bubble_rating bubble_50"></span>      50
# 10    <span class="ui_bubble_rating bubble_50"></span>      50
# 11    <span class="ui_bubble_rating bubble_50"></span>      50
# 12    <span class="ui_bubble_rating bubble_40"></span>      40
# 13    <span class="ui_bubble_rating bubble_50"></span>      50
# 14    <span class="ui_bubble_rating bubble_50"></span>      50
# 15    <span class="ui_bubble_rating bubble_50"></span>      50
# 16    <span class="ui_bubble_rating bubble_50"></span>      50
# 17    <span class="ui_bubble_rating bubble_50"></span>      50
# 18    <span class="ui_bubble_rating bubble_50"></span>      50
# 19    <span class="ui_bubble_rating bubble_50"></span>      50
# 20    <span class="ui_bubble_rating bubble_50"></span>      50
# 21    <span class="ui_bubble_rating bubble_50"></span>      50
# 22    <span class="ui_bubble_rating bubble_40"></span>      40
# 23    <span class="ui_bubble_rating bubble_50"></span>      50
# 24    <span class="ui_bubble_rating bubble_50"></span>      50
# 25    <span class="ui_bubble_rating bubble_40"></span>      40
# 26    <span class="ui_bubble_rating bubble_50"></span>      50
# 27    <span class="ui_bubble_rating bubble_50"></span>      50
# 28    <span class="ui_bubble_rating bubble_40"></span>      40
# 29    <span class="ui_bubble_rating bubble_50"></span>      50
# ...                                                ...     ...
# 2838  <span class="ui_bubble_rating bubble_40"></span>      40
# 2839  <span class="ui_bubble_rating bubble_50"></span>      50
# 2840  <span class="ui_bubble_rating bubble_20"></span>      20
# 2841  <span class="ui_bubble_rating bubble_40"></span>      40
# 2842  <span class="ui_bubble_rating bubble_50"></span>      50
# 2843  <span class="ui_bubble_rating bubble_50"></span>      50
# 2844  <span class="ui_bubble_rating bubble_50"></span>      50
# 2845  <span class="ui_bubble_rating bubble_50"></span>      50
# 2846  <span class="ui_bubble_rating bubble_50"></span>      50
# 2847  <span class="ui_bubble_rating bubble_50"></span>      50
# 2848  <span class="ui_bubble_rating bubble_40"></span>      40
# 2849  <span class="ui_bubble_rating bubble_50"></span>      50
# 2850  <span class="ui_bubble_rating bubble_20"></span>      20
# 2851  <span class="ui_bubble_rating bubble_40"></span>      40
# 2852  <span class="ui_bubble_rating bubble_50"></span>      50
# 2853  <span class="ui_bubble_rating bubble_50"></span>      50
# 2854  <span class="ui_bubble_rating bubble_50"></span>      50
# 2855  <span class="ui_bubble_rating bubble_50"></span>      50
# 2856  <span class="ui_bubble_rating bubble_50"></span>      50
# 2857  <span class="ui_bubble_rating bubble_50"></span>      50
# 2858  <span class="ui_bubble_rating bubble_40"></span>      40
# 2859  <span class="ui_bubble_rating bubble_50"></span>      50
# 2860  <span class="ui_bubble_rating bubble_20"></span>      20
# 2861  <span class="ui_bubble_rating bubble_40"></span>      40
# 2862  <span class="ui_bubble_rating bubble_50"></span>      50
# 2863  <span class="ui_bubble_rating bubble_50"></span>      50
# 2864  <span class="ui_bubble_rating bubble_50"></span>      50
# 2865  <span class="ui_bubble_rating bubble_50"></span>      50
# 2866  <span class="ui_bubble_rating bubble_50"></span>      50
# 2867  <span class="ui_bubble_rating bubble_50"></span>      50
#
#               country
# 0           Wisconsin
# 1               China
# 2              Sweden
# 3      United Kingdom
# 4                 NaN
# 5      United Kingdom
# 6                 NaN
# 7               Texas
# 8            Colorado
# 9          California
# 10           New York
# 11              Spain
# 12           Illinois
# 13                NaN
# 14         New Jersey
# 15                NaN
# 16            Seattle
# 17           Cheshire
# 18             Sweden
# 19               Maui
# 20            Romania
# 21                NaN
# 22     United Kingdom
# 23           New York
# 24            Toronto
# 25             Sweden
# 26          Tennessee
# 27                NaN
# 28            Denmark
# 29             Canada
# ...               ...
# 2838        Wisconsin
# 2839            China
# 2840           Sweden
# 2841   United Kingdom
# 2842              NaN
# 2843   United Kingdom
# 2844              NaN
# 2845            Texas
# 2846         Colorado
# 2847       California
# 2848        Wisconsin
# 2849            China
# 2850           Sweden
# 2851   United Kingdom
# 2852              NaN
# 2853   United Kingdom
# 2854              NaN
# 2855            Texas
# 2856         Colorado
# 2857       California
# 2858        Wisconsin
# 2859            China
# 2860           Sweden
# 2861   United Kingdom
# 2862              NaN
# 2863   United Kingdom
# 2864              NaN
# 2865            Texas
# 2866         Colorado
# 2867       California
#
# [2868 rows x 6 columns]

# %%
# initialize tokenizer
tokenizer = nltk.tokenize.TweetTokenizer()

# define function
def preprocessing(string):
    return tokenizer.tokenize(string.lower())

# %%
documents = df.name.apply(preprocessing)

# %%
# Define count function using a list comprehension.
def count_dictionary(tokenized_doc,dictionary):
    return len([word for word in tokenized_doc if word in dictionary])

# %%
df['positive_liu'] = documents.apply(count_dictionary,dictionary=positive)
df['negative_liu'] = documents.apply(count_dictionary,dictionary=negative)

# %%
df
# Out:
#       Unnamed: 0                                               name  \
# 0              0  Ate here last night with a group of friends.  ...
# 1              1  Awesome!! Delicious food, nice staff.  We had ...
# 2              2  We wanted a nice dinner. We  could place our o...
# 3              3  Restuarant Tight is located off the main shopp...
# 4              4  We concluded our trip to Denmark by stumbling ...
# 5              5  Visited on a Sunday night\nWe booked a table b...
# 6              6  Based on reviews of this establishment, my hus...
# 7              7  Had a late lunch at Tight, ordering off the lu...
# 8              8  A great dinner with most gracious staff for ou...
# 9              9  My husband and I ate here for our last dinner ...
# 10             0  We sat upstairs and had a really delightful lu...
# 11             1  This restaurant was recommended by a friend an...
# 12             2  Nice place for dinner just off the shopping st...
# 13             3  Small dishes Tapas style was served. All three...
# 14             4  Our table was on the second floor—good for peo...
# 15             5  Used TA to find a restaurant and settled on Ti...
# 16             6  We enjoyed our meal at Tight.  I had booked a ...
# 17             7  Lovely restuarant. We were greeted promptly, a...
# 18             8  A very welcoming host that made our visit perf...
# 19             9  Husband and I just had dinner here. I had the ...
# 20             0  This is very centrally located. We tried their...
# 21             1  Found this restaurant after a tip from a local...
# 22             2  Had a very good meal here.\nWhen we booked we ...
# 23             3  Restaurant Tight is an inviting multi-level re...
# 24             4  Came to Tight based on reviews here and Rick S...
# 25             5  A very cozy and nice restaurant with two floor...
# 26             6  Don’t miss this restaurant during your Copenha...
# 27             7  I am currently writing this as I am finishing ...
# 28             8  First time in Copenhagen from Scotland  .. so ...
# 29             9  We used the what’s nearby feature on the app a...
# ...          ...                                                ...
# 2838           0  Ate here last night with a group of friends.  ...
# 2839           1  Awesome!! Delicious food, nice staff.  We had ...
# 2840           2  We wanted a nice dinner. We  could place our o...
# 2841           3  Restuarant Tight is located off the main shopp...
# 2842           4  We concluded our trip to Denmark by stumbling ...
# 2843           5  Visited on a Sunday night\nWe booked a table b...
# 2844           6  Based on reviews of this establishment, my hus...
# 2845           7  Had a late lunch at Tight, ordering off the lu...
# 2846           8  A great dinner with most gracious staff for ou...
# 2847           9  My husband and I ate here for our last dinner ...
# 2848           0  Ate here last night with a group of friends.  ...
# 2849           1  Awesome!! Delicious food, nice staff.  We had ...
# 2850           2  We wanted a nice dinner. We  could place our o...
# 2851           3  Restuarant Tight is located off the main shopp...
# 2852           4  We concluded our trip to Denmark by stumbling ...
# 2853           5  Visited on a Sunday night\nWe booked a table b...
# 2854           6  Based on reviews of this establishment, my hus...
# 2855           7  Had a late lunch at Tight, ordering off the lu...
# 2856           8  A great dinner with most gracious staff for ou...
# 2857           9  My husband and I ate here for our last dinner ...
# 2858           0  Ate here last night with a group of friends.  ...
# 2859           1  Awesome!! Delicious food, nice staff.  We had ...
# 2860           2  We wanted a nice dinner. We  could place our o...
# 2861           3  Restuarant Tight is located off the main shopp...
# 2862           4  We concluded our trip to Denmark by stumbling ...
# 2863           5  Visited on a Sunday night\nWe booked a table b...
# 2864           6  Based on reviews of this establishment, my hus...
# 2865           7  Had a late lunch at Tight, ordering off the lu...
# 2866           8  A great dinner with most gracious staff for ou...
# 2867           9  My husband and I ate here for our last dinner ...
#
#                        location  \
# 0           Waukesha, Wisconsin
# 1              Hong Kong, China
# 2            Sollentuna, Sweden
# 3        London, United Kingdom
# 4                           NaN
# 5       Newquay, United Kingdom
# 6                           NaN
# 7                         Texas
# 8              Aurora, Colorado
# 9     San Francisco, California
# 10      New York City, New York
# 11                Madrid, Spain
# 12            Chicago, Illinois
# 13                          NaN
# 14        Princeton, New Jersey
# 15                          NaN
# 16                      Seattle
# 17                     Cheshire
# 18            Stockholm, Sweden
# 19                         Maui
# 20           Bucharest, Romania
# 21                          NaN
# 22       Surrey, United Kingdom
# 23      New York City, New York
# 24                      Toronto
# 25            Stromstad, Sweden
# 26       Chattanooga, Tennessee
# 27                          NaN
# 28          Copenhagen, Denmark
# 29              Calgary, Canada
# ...                         ...
# 2838        Waukesha, Wisconsin
# 2839           Hong Kong, China
# 2840         Sollentuna, Sweden
# 2841     London, United Kingdom
# 2842                        NaN
# 2843    Newquay, United Kingdom
# 2844                        NaN
# 2845                      Texas
# 2846           Aurora, Colorado
# 2847  San Francisco, California
# 2848        Waukesha, Wisconsin
# 2849           Hong Kong, China
# 2850         Sollentuna, Sweden
# 2851     London, United Kingdom
# 2852                        NaN
# 2853    Newquay, United Kingdom
# 2854                        NaN
# 2855                      Texas
# 2856           Aurora, Colorado
# 2857  San Francisco, California
# 2858        Waukesha, Wisconsin
# 2859           Hong Kong, China
# 2860         Sollentuna, Sweden
# 2861     London, United Kingdom
# 2862                        NaN
# 2863    Newquay, United Kingdom
# 2864                        NaN
# 2865                      Texas
# 2866           Aurora, Colorado
# 2867  San Francisco, California
#
#                                                 bubble  rating  \
# 0     <span class="ui_bubble_rating bubble_40"></span>      40
# 1     <span class="ui_bubble_rating bubble_50"></span>      50
# 2     <span class="ui_bubble_rating bubble_20"></span>      20
# 3     <span class="ui_bubble_rating bubble_40"></span>      40
# 4     <span class="ui_bubble_rating bubble_50"></span>      50
# 5     <span class="ui_bubble_rating bubble_50"></span>      50
# 6     <span class="ui_bubble_rating bubble_50"></span>      50
# 7     <span class="ui_bubble_rating bubble_50"></span>      50
# 8     <span class="ui_bubble_rating bubble_50"></span>      50
# 9     <span class="ui_bubble_rating bubble_50"></span>      50
# 10    <span class="ui_bubble_rating bubble_50"></span>      50
# 11    <span class="ui_bubble_rating bubble_50"></span>      50
# 12    <span class="ui_bubble_rating bubble_40"></span>      40
# 13    <span class="ui_bubble_rating bubble_50"></span>      50
# 14    <span class="ui_bubble_rating bubble_50"></span>      50
# 15    <span class="ui_bubble_rating bubble_50"></span>      50
# 16    <span class="ui_bubble_rating bubble_50"></span>      50
# 17    <span class="ui_bubble_rating bubble_50"></span>      50
# 18    <span class="ui_bubble_rating bubble_50"></span>      50
# 19    <span class="ui_bubble_rating bubble_50"></span>      50
# 20    <span class="ui_bubble_rating bubble_50"></span>      50
# 21    <span class="ui_bubble_rating bubble_50"></span>      50
# 22    <span class="ui_bubble_rating bubble_40"></span>      40
# 23    <span class="ui_bubble_rating bubble_50"></span>      50
# 24    <span class="ui_bubble_rating bubble_50"></span>      50
# 25    <span class="ui_bubble_rating bubble_40"></span>      40
# 26    <span class="ui_bubble_rating bubble_50"></span>      50
# 27    <span class="ui_bubble_rating bubble_50"></span>      50
# 28    <span class="ui_bubble_rating bubble_40"></span>      40
# 29    <span class="ui_bubble_rating bubble_50"></span>      50
# ...                                                ...     ...
# 2838  <span class="ui_bubble_rating bubble_40"></span>      40
# 2839  <span class="ui_bubble_rating bubble_50"></span>      50
# 2840  <span class="ui_bubble_rating bubble_20"></span>      20
# 2841  <span class="ui_bubble_rating bubble_40"></span>      40
# 2842  <span class="ui_bubble_rating bubble_50"></span>      50
# 2843  <span class="ui_bubble_rating bubble_50"></span>      50
# 2844  <span class="ui_bubble_rating bubble_50"></span>      50
# 2845  <span class="ui_bubble_rating bubble_50"></span>      50
# 2846  <span class="ui_bubble_rating bubble_50"></span>      50
# 2847  <span class="ui_bubble_rating bubble_50"></span>      50
# 2848  <span class="ui_bubble_rating bubble_40"></span>      40
# 2849  <span class="ui_bubble_rating bubble_50"></span>      50
# 2850  <span class="ui_bubble_rating bubble_20"></span>      20
# 2851  <span class="ui_bubble_rating bubble_40"></span>      40
# 2852  <span class="ui_bubble_rating bubble_50"></span>      50
# 2853  <span class="ui_bubble_rating bubble_50"></span>      50
# 2854  <span class="ui_bubble_rating bubble_50"></span>      50
# 2855  <span class="ui_bubble_rating bubble_50"></span>      50
# 2856  <span class="ui_bubble_rating bubble_50"></span>      50
# 2857  <span class="ui_bubble_rating bubble_50"></span>      50
# 2858  <span class="ui_bubble_rating bubble_40"></span>      40
# 2859  <span class="ui_bubble_rating bubble_50"></span>      50
# 2860  <span class="ui_bubble_rating bubble_20"></span>      20
# 2861  <span class="ui_bubble_rating bubble_40"></span>      40
# 2862  <span class="ui_bubble_rating bubble_50"></span>      50
# 2863  <span class="ui_bubble_rating bubble_50"></span>      50
# 2864  <span class="ui_bubble_rating bubble_50"></span>      50
# 2865  <span class="ui_bubble_rating bubble_50"></span>      50
# 2866  <span class="ui_bubble_rating bubble_50"></span>      50
# 2867  <span class="ui_bubble_rating bubble_50"></span>      50
#
#               country  positive_liu  negative_liu
# 0           Wisconsin             3             0
# 1               China             6             0
# 2              Sweden             3             1
# 3      United Kingdom             3             0
# 4                 NaN             4             0
# 5      United Kingdom             3             0
# 6                 NaN             1             1
# 7               Texas             4             0
# 8            Colorado             5             0
# 9          California             1             0
# 10           New York             5             0
# 11              Spain             5             0
# 12           Illinois             5             1
# 13                NaN             4             1
# 14         New Jersey             7             0
# 15                NaN             6             1
# 16            Seattle             4             0
# 17           Cheshire             6             1
# 18             Sweden             5             0
# 19               Maui             2             1
# 20            Romania             1             0
# 21                NaN             6             1
# 22     United Kingdom             3             0
# 23           New York             3             2
# 24            Toronto             5             0
# 25             Sweden             4             0
# 26          Tennessee             4             1
# 27                NaN             5             0
# 28            Denmark             6             0
# 29             Canada             2             0
# ...               ...           ...           ...
# 2838        Wisconsin             3             0
# 2839            China             6             0
# 2840           Sweden             3             1
# 2841   United Kingdom             3             0
# 2842              NaN             4             0
# 2843   United Kingdom             3             0
# 2844              NaN             1             1
# 2845            Texas             4             0
# 2846         Colorado             5             0
# 2847       California             1             0
# 2848        Wisconsin             3             0
# 2849            China             6             0
# 2850           Sweden             3             1
# 2851   United Kingdom             3             0
# 2852              NaN             4             0
# 2853   United Kingdom             3             0
# 2854              NaN             1             1
# 2855            Texas             4             0
# 2856         Colorado             5             0
# 2857       California             1             0
# 2858        Wisconsin             3             0
# 2859            China             6             0
# 2860           Sweden             3             1
# 2861   United Kingdom             3             0
# 2862              NaN             4             0
# 2863   United Kingdom             3             0
# 2864              NaN             1             1
# 2865            Texas             4             0
# 2866         Colorado             5             0
# 2867       California             1             0
#
# [2868 rows x 8 columns]

# %%
# import nltk.sentiment
import nltk
nltk.download('vader_lexicon')
import nltk.sentiment
# initialize the vader function
vader = nltk.sentiment.vader.SentimentIntensityAnalyzer()
# apply the function and convert to dataframe
vader_df = pd.DataFrame(list(df['name'].apply(vader.polarity_scores)))
# rename columns adding the 'vader_' prefix using a list comprehension
vader_df.columns = ['vader_'+col for col in vader_df.columns]
# merge with original dataframe
df = pd.concat([df,vader_df],axis=1)
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\jtoft\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
from afinn import Afinn
afinn = Afinn()
df['afinn'] = df.name.apply(afinn.score)

# %%
# # define columns
sentiment_columns = ['afinn','positive_liu','negative_liu']+[col for col in df.columns if 'vader_' in col]
hue = 'rating'
sns.pairplot(df.sample(1000)[sentiment_columns+[hue]],hue=hue)

# %%
# Pick documents with positive LIU classification
positive_liu_reviews = df[((df.positive_liu-df.negative_liu)>0)]

# We, now, want to get the indeces of these documents and the words within them LUI classified as positive:
for idx in df.iloc[df[((df.positive_liu-df.negative_liu)>0)].vader_compound.sort_values().index].head().index:
    print(idx,set(documents[idx])&positive)

# # So that, in a final step, we can pick one and look at the whole text to assess why LUI and VADER disagree:
# print(df.name[235])

# #LIU defines 'well' as a positive word. However, 'well' is in the context of 'not' well.  
# print(vader.polarity_scores('the videos are not well organized'))

# # LIU defines 'work' as a positive word. However, here it is in the context of 'hard work'
# print(vader.polarity_scores('find it hard to work through'))

## The VADER understands these negations.  

df.dropna(inplace = True) 
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-49f84a4ed4c0> in <module>
#       3
#       4 # We, now, want to get the indeces of these documents and the words within them LUI classified as positive:
# ----> 5 for idx in df.iloc[df[((df.positive_liu-df.negative_liu)>0)].vader_compound.sort_values().index].head().index:
#       6     print(idx,set(documents[idx])&positive)
#       7
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'vader_compound'
